# %%
EXPERIMENT 10
STUDY OF PANDAS LIBRARY IN PYTHON
NIKUNJ DEEP UPADHYAY
ENTC B1
25070123081
# Out:
#   File "/tmp/ipython-input-2240630835.py", line 1
#     EXPERIMENT 10
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

s= pd.Series([10,20,30,40])
print(s)

# %%
#CREATE DATAFRAME
data = {
    "NAME":["A","B","C"],
    "MARKS":[85,90,78]
}
df = pd.DataFrame(data)
print(df)

# %%
# FIND THE STRUCTURE OF THE DATAFRAME
d=df.shape
print(d)
# Out:
# (3, 2)

# %%
f=df.ndim
print(f)
# Out:
# 2

# %%
ss=df.size
print(ss)
# Out:
# 6

# %%
# DISPLAY COLUMN NAMES
c=df.columns
print(c)
# Out:
# Index(['NAME', 'MARKS'], dtype='object')

# %%
dd=df.dtypes
print(dd)
# Out:
# NAME     object
# MARKS     int64
# dtype: object

# %%
n=df["NAME"]
print(n)
# Out:
# 0    A
# 1    B
# 2    C
# Name: NAME, dtype: object

# %%
m=df["MARKS"]
print(m)
# Out:
# 0    88
# 1    90
# 2    78
# Name: MARKS, dtype: int64

# %%
#Access name of first row
df = pd.DataFrame(data)
print(df)
df.loc[0,"NAME"]
# Out:
#   NAME  MARKS
# 0    A     85
# 1    B     90
# 2    C     78
# 'A'

# %%
#Access ELEMENTS
df = pd.DataFrame(data)
print(df)
print(df.loc[0,"NAME"])
print(df.iloc[2,1])
# Out:
#   NAME  MARKS
# 0    A     85
# 1    B     90
# 2    C     78
# A
# 78

# %%
# ADD A NEW COLUMN
df["Grade"]=["First Class","Distinction","Second Class"]
print(df)
# Out:
#   NAME  MARKS         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Update Data in DataFrame
#Change marks of student A to 88.

df.iloc[0,1]=88
print(df)
# Out:
#   NAME  MARKS         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
#Delete a column
# Re-add the 'Grade' column to ensure it exists for deletion demonstration
# This addresses the KeyError: "['Grade'] not found in axis" because df currently lacks 'Grade'.
# Assuming df has 3 rows based on its current state (NAME, MARKS)
df["Grade"]=["First Class","Distinction","Second Class"]

df1=df.drop("Grade",axis=1)
print(df)
print(df1)
# Out:
#   NAME  MARKS         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class
#   NAME  MARKS
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Perform Basic Stastical Analysis
mean1=df["MARKS"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
min1=df["MARKS"].min()
min1
# Out:
# 78

# %%
max1=df["MARKS"].max()
max1
# Out:
# 90

# %%
#DISPLAY STUDENTS SCORING MORE THAN 80
df[df["MARKS"]>80]
# Out:
#   NAME  MARKS
# 0    A     88
# 1    B     90
